# %%
import pandas as pd

# %%
data = pd.read_csv('flat_data_v2_4122019.csv')
# Out:
# c:\users\ilya kaftanov\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3044: DtypeWarning: Columns (0,5,11,12,13,14,22,25,30,38,42,44,46,55,56,57,59,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#   allRoomsArea  balconiesCount  basicProfiScore  category  childrenAllowed  \
# 0            0               0                1  flatRent              NaN
# 1            0               0                1  flatRent              NaN
# 2            0               0                1  flatRent              NaN
# 3            0               0                1  flatRent              NaN
# 4            0               0                1  flatRent              NaN
#
#   cianOnly  combinedWcsCount             creationDate dealType  \
# 0    False               NaN  2019-04-10 13:06:55.413     rent
# 1    False               NaN  2019-03-05 18:23:07.630     rent
# 2    False               NaN  2018-08-09 18:23:51.497     rent
# 3    False               NaN  2019-04-09 20:12:51.040     rent
# 4    False               NaN  2019-02-25 14:42:49.043     rent
#
#    demolishedInMoscowProgramm  ... flatPriceDeposit buildYear  \
# 0                         0.0  ...         250000.0       NaN
# ...

# %%
data['fullUrl'].shape
# Out:
# (8216,)

# %%
data[data['fullUrl'].duplicated()]['fullUrl']
# Out:
# 68      https://www.cian.ru/rent/flat/201156001/
# 69      https://www.cian.ru/rent/flat/202327359/
# 70      https://www.cian.ru/rent/flat/202277885/
# 71      https://www.cian.ru/rent/flat/197798780/
# 72      https://www.cian.ru/rent/flat/202878778/
# 73      https://www.cian.ru/rent/flat/198009759/
# 74      https://www.cian.ru/rent/flat/201162958/
# 75      https://www.cian.ru/rent/flat/201022348/
# 76      https://www.cian.ru/rent/flat/202790081/
# 77      https://www.cian.ru/rent/flat/199233368/
# 78      https://www.cian.ru/rent/flat/199910010/
# 79      https://www.cian.ru/rent/flat/199172442/
# 80      https://www.cian.ru/rent/flat/201695646/
# 81      https://www.cian.ru/rent/flat/197958084/
# 82      https://www.cian.ru/rent/flat/202888671/
# 83      https://www.cian.ru/rent/flat/188519145/
# 84      https://www.cian.ru/rent/flat/193256004/
# 85      https://www.cian.ru/rent/flat/201067014/
# 86      https://www.cian.ru/rent/flat/201695646/
# ...

# %%
data[data['fullUrl'] == 'https://www.cian.ru/rent/flat/201156001/']
# Out:
#      allRoomsArea  balconiesCount  basicProfiScore  category  childrenAllowed  \
# 50              0               0                1  flatRent              NaN
# 68              0               0                1  flatRent              NaN
# 89              0               0                1  flatRent              NaN
# 108             0               0                1  flatRent              NaN
# 199             0               0                1  flatRent              NaN
# 220             0               0                1  flatRent              NaN
# 311             0               0                1  flatRent              NaN
# 404             0               0                1  flatRent              NaN
# 422             0               0                1  flatRent              NaN
# 443             0               0                1  flatRent              NaN
# 459             0               0                1  flatRent              NaN
# ...
